# %% [markdown]
# How runtime has changed over time, and whether this can be correlated to other factors.

# %%
# %matplotlib notebook
#import dependecies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#read the csv into dataframe
netflix_shows_df = pd.read_csv('Resources/clean_netflix_shows.csv',index_col=0)

# %%
#display dataframe
netflix_shows_df
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 497        Taylor Swift: Reputation Stadium Tour           Concert Film
# 498  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 499                      Springsteen on Broadway           One-man show
# 500    Emicida: AmarElo - It's All For Yesterday            Documentary
# 501     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language  \
# 0       August 5, 2019       58         2.5          English/Japanese
# 1      August 21, 2020       81         2.6                   Spanish
# 2    December 26, 2019       79         2.6                   Italian
# 3     January 19, 2018       94         3.2                   English
# 4     October 30, 2020       90         3.4                     Hindi
# ..                 ...      ...         ...                       ...
# 497  December 31, 2018      125         8.4                   English
# 498    October 9, 2015       91         8.4  English/Ukranian/Russian
# 499  December 16, 2018      153         8.5                   English
# 500   December 8, 2020       89         8.6                Portuguese
# 501    October 4, 2020       83         9.0                   English
#
#      Omdb Review Score Omdb Review Count     Month  Year  Financial Quarter
# 0                  2.5             1,515    August  2019                  3
# 1                  3.9                31    August  2020                  3
# 2                  2.6             1,201  December  2019                  4
# 3                  3.2            32,162   January  2018                  1
# 4                  3.4             1,048   October  2020                  4
# ..                 ...               ...       ...   ...                ...
# 497                8.4             4,349  December  2018                  4
# 498                8.4            13,353   October  2015                  4
# 499                8.5             2,001  December  2018                  4
# 500                8.6             1,136  December  2020                  4
# 501                9.0            28,028   October  2020                  4
#
# [502 rows x 11 columns]

# %%
netflix_shows_df.dtypes
# Out:
# Title                 object
# Genre                 object
# Premiere              object
# Runtime                int64
# IMDB Score           float64
# Language              object
# Omdb Review Score    float64
# Omdb Review Count     object
# Month                 object
# Year                   int64
# Financial Quarter      int64
# dtype: object

# %%
# Figure out the minimum and maximum Runtime
print(netflix_shows_df["Runtime"].max())
print(netflix_shows_df["Runtime"].min())
# Out:
# 209
# 4

# %%
yearly_count = netflix_shows_df["Year"].value_counts()
yearly_count
# Out:
# 2020    145
# 2019    109
# 2018     90
# 2017     63
# 2021     56
# 2016     29
# 2015      9
# 2014      1
# Name: Year, dtype: int64

# %%
grouped_yearlycount = netflix_shows_df.groupby("Year")
print(grouped_yearlycount)
grouped_count = grouped_yearlycount.size()
grouped_count.head()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000025A4B1A3BB0>
# Year
# 2014     1
# 2015     9
# 2016    29
# 2017    63
# 2018    90
# dtype: int64

# %%
average_yearly_runtime = netflix_shows_df .groupby("Year")["Runtime"].mean()

average_yearly_runtime.head(10)
# Out:
# Year
# 2014     81.000000
# 2015     90.444444
# 2016     92.758621
# 2017     92.793651
# 2018     94.844444
# 2019     88.082569
# 2020     94.262069
# 2021    103.267857
# Name: Runtime, dtype: float64

# %%
#Genre data
Genre_data = netflix_shows_df["Genre"].value_counts()
Genre_data.head()
# Out:
# Documentary        143
# Drama               63
# Comedy              36
# Romantic comedy     35
# Thriller            28
# Name: Genre, dtype: int64

# %%
#groupby on Year
Year_groupby = netflix_shows_df.groupby('Year')
runtime_mean= Year_groupby['Runtime'].mean()

# %%
runtime_mean
# Out:
# Year
# 2014     81.000000
# 2015     90.444444
# 2016     92.758621
# 2017     92.793651
# 2018     94.844444
# 2019     88.082569
# 2020     94.262069
# 2021    103.267857
# Name: Runtime, dtype: float64

# %%
#Group by Genre
Genre_groupby = netflix_shows_df.groupby('Genre')
runtime_mean = Genre_groupby['Runtime'].mean()

# %%
#plotting a scatter plot for the Genre 
x_axis =netflix_shows_df['Genre'].unique()
y_axis = runtime_mean
plt.figure(figsize=(15,10))
plt.scatter(x_axis,y_axis,color = 'Blue')
plt.xticks(rotation=90)
plt.xlabel("Genre")
plt.ylabel("Average Runtime ")
plt.title("Genre vs Average Runtime of Netflix Shows ")
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
#plotting a Bar plot for the Genre 
x_axis =netflix_shows_df['Genre'].unique()
y_axis =runtime_mean
plt.figure(figsize=(25,15))
plt.bar(x_axis, y_axis, color="b", align="center")
plt.xticks(rotation=90)

# Give the chart a title, x label, and y label
plt.title("Genre vs Average Runtime of Netflix Shows")
plt.xlabel("Genre")
plt.ylabel("Average Runtime")
# Out:
# <img src="data:image/png;base64,..." width="2500">
# Text(0, 0.5, 'Average Runtime')

# %%
#plotting a Bar plot for the Year 
x_axis =netflix_shows_df["Year"].unique()
y_axis =runtime_mean
plt.figure(figsize=(4,4))
plt.bar(x_axis, y_axis, color="b", align="center")
plt.xticks(rotation=90)
plt.savefig("output/Year_vs_Average Runtime of Netflix Shows.png")
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
sorted_on_Runtime = runtime_mean.sort_values()
sorted_on_Runtime
# Out:
# Genre
# Anime / Short              4.00
# Animation / Short         10.75
# Musical / Short           15.00
# Drama / Short             17.00
# Aftershow / Interview     24.25
#                           ...
# Horror anthology         144.00
# War drama                145.50
# Zombie/Heist             148.00
# Heist film/Thriller      149.00
# Anthology/Dark comedy    149.00
# Name: Runtime, Length: 107, dtype: float64

# %%
x_axis =netflix_shows_df['Genre'].unique()
y_axis =sorted_on_Runtime 
plt.figure(figsize=(10,25)) 
plt.barh(x_axis, y_axis, color="b", align="center")
plt.xticks(rotation=90)
plt.show(block=True);

# Give the chart a title, x label, and y label
plt.title("Genre vs Average Runtime of Netflix Shows")
plt.xlabel("Genre")
plt.ylabel("Average Runtime")
plt.tight_layout()
plt.savefig("output/Genre_vs_Average Runtime of Netflix Shows.png")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
x_axis =netflix_shows_df['Genre'].unique()
y_axis =runtime_mean
plt.figure(figsize=(10,25)) 
plt.barh(x_axis, y_axis, color="b", align="center")
plt.xticks(rotation=90)
plt.show(block=True);

# Give the chart a title, x label, and y label
plt.title("Genre vs Average Runtime of Netflix Shows")
plt.xlabel("Genre")
plt.ylabel("Average Runtime")
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
sorted_on_Genre = netflix_shows_df.sort_values(by = ["Genre"])
sorted_on_Genre
# Out:
#                             Title         Genre           Premiere  Runtime  \
# 234                         Polar        Action   January 25, 2019      118
# 315                    Extraction        Action     April 24, 2020      117
# 128                   Point Blank        Action      July 12, 2019       86
# 34                     Sentinelle        Action      March 5, 2021       80
# 5                           Drive        Action   November 1, 2019      147
# ..                            ...           ...                ...      ...
# 190                   War Machine    War-Comedy       May 26, 2017      122
# 205                    The Killer       Western  November 10, 2017       99
# 439  The Ballad of Buster Scruggs       Western  November 16, 2018      132
# 42               The Ridiculous 6       Western  December 11, 2015      119
# 165              Army of the Dead  Zombie/Heist       May 21, 2021      148
#
#      IMDB Score    Language  Omdb Review Score Omdb Review Count     Month  \
# 234         6.3     English                6.3            79,753   January
# 315         6.7     English                6.7           171,447     April
# 128         5.7     English                7.3            19,135      July
# 34          4.7      French                4.7             6,717     March
# 5           3.5       Hindi                7.8           587,337  November
# ..          ...         ...                ...               ...       ...
# 190         6.0     English                6.0            43,226       May
# 205         6.1  Portuguese                4.7             1,078  November
# 439         7.3     English                7.3           130,192  November
# 42          4.8     English                4.8            45,838  December
# 165         5.9     English                5.8           128,898       May
#
#      Year  Financial Quarter
# 234  2019                  1
# 315  2020                  2
# 128  2019                  3
# 34   2021                  1
# 5    2019                  4
# ..    ...                ...
# 190  2017                  2
# 205  2017                  4
# 439  2018                  4
# 42   2015                  4
# 165  2021                  2
#
# [502 rows x 11 columns]

# %%
sorted_on_Runtime = runtime_mean.sort_values()
sorted_on_Runtime
# Out:
# Genre
# Anime / Short              4.00
# Animation / Short         10.75
# Musical / Short           15.00
# Drama / Short             17.00
# Aftershow / Interview     24.25
#                           ...
# Horror anthology         144.00
# War drama                145.50
# Zombie/Heist             148.00
# Heist film/Thriller      149.00
# Anthology/Dark comedy    149.00
# Name: Runtime, Length: 107, dtype: float64
