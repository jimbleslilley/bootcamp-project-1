# %%
# %matplotlib notebook
import pandas as pd 
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
runtime_df = pd.read_csv('../Resources/clean_netflix_shows.csv',index_col= 0)
runtime_df.head(10)
# Out:
#                              Title                    Genre  \
# 0                  Enter the Anime              Documentary
# 1                      Dark Forces                 Thriller
# 2                          The App    Science fiction/Drama
# 3                   The Open House          Horror thriller
# 4                      Kaali Khuhi                  Mystery
# 5                            Drive                   Action
# 6  The Last Days of American Crime      Heist film/Thriller
# 7                          Paradox  Musical/Western/Fantasy
# 8               Sardar Ka Grandson                   Comedy
# 9             Searching for Sheela              Documentary
#
#             Premiere  Runtime  IMDB Score          Language  \
# 0     August 5, 2019       58         2.5  English/Japanese
# 1    August 21, 2020       81         2.6           Spanish
# 2  December 26, 2019       79         2.6           Italian
# 3   January 19, 2018       94         3.2           English
# 4   October 30, 2020       90         3.4             Hindi
# 5   November 1, 2019      147         3.5             Hindi
# 6       June 5, 2020      149         3.7           English
# 7     March 23, 2018       73         3.9           English
# 8       May 18, 2021      139         4.1             Hindi
# 9     April 22, 2021       58         4.1           English
#
#    Omdb Review Score Omdb Review Count     Month  Year  Financial Quarter
# 0                2.5             1,515    August  2019                  3
# 1                3.9                31    August  2020                  3
# 2                2.6             1,201  December  2019                  4
# 3                3.2            32,162   January  2018                  1
# 4                3.4             1,048   October  2020                  4
# 5                7.8           587,337  November  2019                  4
# 6                3.7            10,245      June  2020                  2
# 7                4.6             3,160     March  2018                  1
# 8                4.2             3,955       May  2021                  2
# 9                4.1               573     April  2021                  2

# %% [markdown]
# ## Finding a relation beteween IMDB scores and Runtime

# %%
#groupby on IMDB score
imdb_groupby = runtime_df.groupby('IMDB Score')
runtime_mean= imdb_groupby['Runtime'].mean()

# %%
#plotting a scatter plot for the imdb scores
x_axis = runtime_df['IMDB Score'].unique()
y_axis = runtime_mean
plt.scatter(x_axis,y_axis,color = 'Red')
plt.xlabel("IMDB scores")
plt.ylabel("Average Runtime")
plt.title("IMDB scores vs Average Runtime of Netflix Originals")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'IMDB scores vs Average Runtime of Netflix Originals')

# %%
# calculating and plotting the linear regression for the imdb scores 
corr,_ = st.pearsonr(x_axis,y_axis)
print(f"The correlation coefficient between the IMDB score and the average runtime on netflix is {corr}")

# finding linear regression values and plotting them on scatter plot
rt_slope,rt_int,rt_r,rt_p,rt_std_err = st.linregress(x_axis,y_axis)
rt_fit = rt_slope*x_axis + rt_int
#plotting
plt.plot(x_axis,rt_fit,"--")
plt.savefig("../Output/IMDB scores vs Average Runtime.png")
# Out:
# The correlation coefficient between the IMDB score and the average runtime on netflix is 0.057233243229455256

# %% [markdown]
# ## Find a relation between IMDB Score and Runtime on each Genre

# %%
#plot initiate
genre_groupby = runtime_df.groupby('Genre')
runtime_pergenre = genre_groupby['Runtime'].mean()
score_pergenre = genre_groupby['IMDB Score'].mean()

# %%
#plotting the runtime versus IMDB score for each genre
plt.scatter(score_pergenre,runtime_pergenre,color= "Red")
plt.xlabel("Average IMDB scores per genre")
plt.ylabel("Average Runtime per genre")
plt.title("IMDB scores vs Average Runtime Per Genre")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'IMDB scores vs Average Runtime Per Genre')

# %%
# calculating and plotting the linear regression 
corr,_ = st.pearsonr(score_pergenre,runtime_pergenre)
print(f"The correlation coefficient between the IMDB score and the average runtime on netflix is {corr}")

# finding linear regression values and plotting them on scatter plot
genre_slope,genre_int,genre_r,genre_p,genre_std_err = st.linregress(score_pergenre,runtime_pergenre)
genre_fit = genre_slope*score_pergenre + genre_int

#plotting
plt.plot(score_pergenre,genre_fit,"--")
plt.savefig("../Output/IMDB scores vs Average Runtime per genre.png")
# Out:
# The correlation coefficient between the IMDB score and the average runtime on netflix is -0.11717285835391689
